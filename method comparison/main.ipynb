# %%
from simulation import *
from transPCA import *

run_simulation(iterate = 30)
# Out:
# Average Error (Scenario 1):
#             K=7   K=13   K=19   K=25
# individual PCA  0.2104  0.2083  0.2128  0.2123
# selected GB     0.1489  0.1320  0.1309  0.1234
# blind GB        0.1350  0.1263  0.1246  0.1203
# blind PCA       0.5108  0.5211  0.5308  0.5343
#
# Average Error (Scenario 2):
#             K=7   K=13   K=19   K=25
# individual PCA  0.2117  0.2134  0.2087  0.2108
# selected GB     0.1649  0.1467  0.1479  0.1304
# blind GB        0.1745  0.1518  0.1441  0.1361
# blind PCA       0.5395  0.5397  0.5326  0.5366
#
# Average Error (Scenario 3):
#             K=7   K=13   K=19   K=25
# individual PCA  0.2145  0.2132  0.2105  0.2122
# selected GB     0.1573  0.1377  0.1384  0.1394
# blind GB        0.1988  0.1941  0.1935  0.1927
# blind PCA       0.5512  0.5514  0.5584  0.5550
#
# Total runtime: 13.58 minutes
